# %%
import numpy as np
import matplotlib.pyplot as plt
name='test'

# %%
a = np.loadtxt('{}.txt.gz'.format(name), delimiter=',')
fig = plt.figure(figsize=(12,6))
plt.plot(a[0],a[1])
plt.xlabel('Time')
plt.ylabel('Acceleration')
plt.legend(['X', 'Y'])
